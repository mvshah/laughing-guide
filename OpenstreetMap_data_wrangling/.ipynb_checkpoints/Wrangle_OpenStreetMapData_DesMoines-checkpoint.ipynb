# %% [markdown]
# #### This file is entire code for data wrangling of OpenStreetMap Data of Des Moines City.

# %%
# import required modules
import requests
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict
import csv
import codecs
import cerberus
import schema
import os

# %%
# Assign a variable for the osm file
des_moines_info = "des_moines.osm"

# %%
# This function count the number of each tag in the data for des moines osm file
#This function can be found in map_parser.py

def count_tags(filename):
        # YOUR CODE HERE
        store_tags = {}
        for _, val in ET.iterparse(filename):
            if val.tag in store_tags:
                store_tags[val.tag] += 1
            else:
                store_tags[val.tag] = 1
        return store_tags  

pprint.pprint(count_tags(des_moines_info))
# Out:
# {'bounds': 1,
#  'member': 8707,
#  'meta': 1,
#  'nd': 1073070,
#  'node': 915603,
#  'note': 1,
#  'osm': 1,
#  'relation': 810,
#  'tag': 335790,
#  'way': 64668}

# %%
# This function is used for checking Contents of Tags for Bad Characters   
# This function can be found in map_parser.py

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        # YOUR CODE HERE
        
        keycontents = element.attrib['k']
        if(re.match(lower, keycontents) != None):
            keys["lower"] = keys["lower"] + 1
        elif(re.match(lower_colon, keycontents) != None):
            keys["lower_colon"] = keys["lower_colon"] + 1
        elif(re.match(problemchars, keycontents) != None):
            keys["problemchars"] = keys["problemchars"] + 1
        else:
            #print(keycontents)
            keys["other"] = keys["other"] + 1
        
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys

pprint.pprint(process_map(des_moines_info))
# Out:
# {'lower': 151730, 'lower_colon': 130681, 'other': 53379, 'problemchars': 0}

# %%
## The code in this cell will give a list of the unique users that contributed to the file provided
## This function can be found in map_parser.py

def get_user(element):
    return element.attrib["uid"]


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if 'uid' in element.attrib:
            users.add(get_user(element))

    return users

pprint.pprint(len(process_map(des_moines_info)))
# Out:
# 469

# %%
## The following code is used for auditing the street names and improving them. 
## The code can be found can by found in audit_update_street_types.ipynb
OSMFILE = "des_moines.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Circle"]

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r", encoding="utf8")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

st_types = audit(OSMFILE)
pprint.pprint(dict(st_types))
# Out:
# {'0.1': {'Ala 680 PM 0.1'},
#  '1': {'Prospect Rd #1'},
#  '114': {'West Evelyn Avenue Suite #114'},
#  '201': {'Great America Pkwy Ste 201'},
#  '4A': {'Saratoga Avenue Bldg 4A'},
#  '6': {'Martin Avenue #6', 'Pruneridge Ave #6'},
#  '7.1': {'Hwy 17 PM 7.1'},
#  '81': {'Concourse Dr #81'},
#  'Alameda': {'The Alameda'},
#  'Alley': {'Fountain Alley'},
#  'Ave': {'1425 E Dunne Ave',
#          'Blake Ave',
#          'Cabrillo Ave',
#          'Cherry Ave',
#          'E Duane Ave',
#          'Foxworthy Ave',
#          'Greenbriar Ave',
#          'Hillsdale Ave',
#          'Hollenbeck Ave',
#          'Meridian Ave',
#          'N Blaney Ave',
#          'Saratoga Ave',
#          'Seaboard Ave',
#          'The Alameda Ave',
#          'W Washington Ave',
#          'Walsh Ave',
#          'Westfield Ave'},
#  'Barcelona': {'Calle de Barcelona'},
#  'Bascom': {'S. Bascom'},
#  'Bellomy': {'Bellomy'},
#  'Blvd': {'Los Gatos Blvd',
#           'McCarthy Blvd',
#           'Mission College Blvd',
#           'N McCarthy Blvd',
#           'Palm Valley Blvd',
#           'Santa Teresa Blvd',
#           'Stevens Creek Blvd'},
#  'Blvd.': {'Los Gatos Blvd.'},
#  'Boulvevard': {'Los Gatos Boulvevard'},
#  'Broadway': {'Broadway'},
#  'CA': {'Zanker Road, San Jose, CA', 'Zanker Rd., San Jose, CA'},
#  'Cir': {'Celadon Cir'},
#  'Ct': {'Perivale Ct'},
#  'Dr': {'1350 S Park Victoria Dr',
#         '1490 S Park Victoria Dr',
#         'Fountain Oaks Dr',
#         'Linwood Dr',
#         'Minto Dr',
#         'Oakmead Village Dr',
#         'Samaritan Dr'},
#  'East': {'Vanderbilt Court East', 'Rio Robles East', 'Park Circle East'},
#  'Esquela': {'Camina Esquela'},
#  'Expressway': {'Almaden Expressway',
#                 'Central Expressway',
#                 'East Capitol Expressway',
#                 'Lawrence Expressway',
#                 'Montague Expressway',
#                 'San Tomas Expressway',
#                 'Southwest Expressway',
#                 'West Capitol Expressway'},
#  'Flores': {'Terreno De Flores'},
#  'Franklin': {'Franklin'},
#  'Hamilton': {'Mount Hamilton'},
#  'Highway': {'Monterey Highway',
#              'Old Bayshore Highway',
#              'Old Santa Cruz Highway'},
#  'Hill': {'Blossom Hill'},
#  'Hwy': {'Monterey Hwy'},
#  'Julian': {'West Julian'},
#  'Ln': {'Branham Ln', 'Barber Ln', 'Gaundabert Ln'},
#  'Loop': {'Village View Loop', 'Infinite Loop'},
#  'Luna': {'Calle de Luna'},
#  'Madrid': {'Corte de Madrid'},
#  'Mall': {'Franklin Mall'},
#  'Marino': {'Via San Marino'},
#  'Montaña': {'Vista Montaña'},
#  'Napoli': {'Via Napoli'},
#  'Oaks': {'North Fair Oaks'},
#  'Oro': {'Via del Oro'},
#  'Palamos': {'Via Palamos'},
#  'Paviso': {'Via Paviso'},
#  'Plaza': {'Portal Plaza', 'Rivermark Plaza'},
#  'Portofino': {'Via Portofino'},
#  'Presada': {'Paseo Presada'},
#  'Rd': {'Berryessa Rd',
#         'Homestead Rd',
#         'Mt Hamilton Rd',
#         'Mt. Hamilton Rd',
#         'Quimby Rd',
#         'San Antonio Valley Rd',
#         'Saratoga Los Gatos Rd',
#         'Silver Creek Valley Rd',
#         'Wolfe Rd'},
#  'Real': {'E El Camino Real',
#           'East El Camino Real',
#           'El Camino Real',
#           'West El Camino Real'},
#  'Row': {'Santana Row'},
#  'Saratoga': {'El Paseo de Saratoga'},
#  'Seville': {'Corte de Seville'},
#  'Sorrento': {'Via Sorrento'},
#  'St': {'N 5th St', 'Casa Verde St', 'Monroe St'},
#  'Terrace': {'Amherst Terrace',
#              'Anaheim Terrace',
#              'Avon Terrace',
#              'Avoset Terrace',
#              'Belmont Terrace',
#              'Brea Terrace',
#              'Bridgeport Terrace',
#              'Bristol Terrace',
#              'Cedarbrook Terrace',
#              'Costa Mesa Terrace',
#              'Crown Point Terrace',
#              'Fontana Terrace',
#              'Hobart Terrace',
#              'Hogarth Terrace',
#              'Holthouse Terrace',
#              'Isla Vista Terrace',
#              'Karby Terrace',
#              'Kearny Terrace',
#              'Lautrec Terrace',
#              'Lessing Terrace',
#              'Leuven Terrace',
#              'Liege Terrace',
#              'Manet Terrace',
#              'Markham Terrace',
#              'Miller Terrace',
#              'Oak Point Terrace',
#              'Panache Terrace',
#              'Pasito Terrace',
#              'Pennyroyal Terrace',
#              'Pescadero Terrace',
#              'Pine Pass Terrace',
#              'Pinnacles Terrace',
#              'Pismo Terrace',
#              'Pyracantha Terrace',
#              'Raines Terrace',
#              'Redondo Terrace',
#              'Reston Terrace',
#              'Riorden Terrace',
#              'Santa Rosalia Terrace',
#              'Satsuma Terrace',
#              'Seneca Terrace',
#              'Spencer Terrace',
#              'Springfield Terrace',
#              'Windsor Terrace',
#              'Yellowstone Terrace'},
#  'Volante': {'Via Volante'},
#  'Walk': {'Paseo de San Antonio Walk'},
#  'Way': {'Albright Way',
#          'Alderbrook Way',
#          'All America Way',
#          'Allison Way',
#          'Almaden Express Way',
#          'Altair Way',
#          'Arata Way',
#          'Aries Way',
#          'Barnsley Way',
#          'Belfry Way',
#          'Berwick Way',
#          'Bianchi Way',
#          'Big Basin Way',
#          'Blanchard Way',
#          'Brahms Way',
#          'Candlelight Way',
#          'Carick Way & Ravens Place Way',
#          'Carlisle Way',
#          'Cartwright Way',
#          'Cheshire Way',
#          'Cisco Way',
#          'Clifden Way',
#          'Colt Way',
#          'Connemara Way',
#          'Danromas Way',
#          'Dartshire Way',
#          'Devonshire Way',
#          'Dial Way',
#          'Dorset Way',
#          'Dublin Way',
#          'Duncardine Way',
#          'Dunford Way',
#          'Dunholme Way',
#          'Dunnock Way',
#          'Durshire Way',
#          'Embedded Way',
#          'Enterprise Way',
#          'Epic Way',
#          'Erin Way',
#          'Farmingham Way',
#          'Felton Way',
#          'Fife Way',
#          'Firebird Way',
#          'Flamingo Way',
#          'Flicker Way',
#          'Flin Way',
#          'Forge Way',
#          'Gillick Way',
#          'Hamilton Way',
#          'Hermocilla Way',
#          'Holger Way',
#          'Humewick Way',
#          'Hunter Way',
#          'Innovation Way',
#          'John Way',
#          'Kingfisher Way',
#          'Larry Way',
#          'Las Ondas Way',
#          'Lilac Way',
#          'Locksunart Way',
#          'Longfellow Way',
#          'Mallard Way',
#          'Mandarin Way',
#          'Marie P. DeBartolo Way',
#          'Martinwood Way',
#          'Miette Way',
#          'Milky Way',
#          'Moreland Way',
#          'Nandina Way',
#          'Nelson Way',
#          'Normandy Way',
#          'Patriot Way',
#          'Poppy Way',
#          'Primrose Way',
#          'Prince Edward Way',
#          'Pyrus Way',
#          'Queensbridge Way',
#          'Revelstoke Way',
#          'Ridgeview Way',
#          'Robindell Way',
#          'Ryland Park Way',
#          'Saich Way',
#          'Sakura Way',
#          'Samson Way',
#          'San Luis Way',
#          'San Luisito Way',
#          'Senate Way',
#          'Serra Way',
#          'Shelburne Way',
#          'Squirewood Way',
#          'Sturgeon Way',
#          'Tangerine Way',
#          'Tartarian Way',
#          'Terry Way',
#          'Tomlin Way',
#          'Tonita Way',
#          'Ward Way',
#          'Westlynn Way',
#          'Whitney Way',
#          'Wildflower Way',
#          'Willowbrook Way',
#          'Wilson Way',
#          'Windsor Way',
#          'Woodbank Way',
#          'Woz Way',
#          'Zinfandel Way'},
#  'West': {'Park Circle West', 'Vanderbilt Court West'},
#  'Winchester': {'Winchester'},
#  'ave': {'wilcox ave'},
#  'court': {'Cortona court'},
#  'robles': {'rio robles'},
#  'street': {'N 1st street'},
#  'yes': {'yes'}}

# %%
-
# Out:
# El Camino Real => El Camino Real
# E El Camino Real => E El Camino Real
# East El Camino Real => East El Camino Real
# West El Camino Real => West El Camino Real
# N Blaney Ave => N Blaney Avenue
# E Duane Ave => E Duane Avenue
# Blake Ave => Blake Avenue
# Hillsdale Ave => Hillsdale Avenue
# Cabrillo Ave => Cabrillo Avenue
# Foxworthy Ave => Foxworthy Avenue
# Westfield Ave => Westfield Avenue
# Saratoga Ave => Saratoga Avenue
# 1425 E Dunne Ave => 1425 E Dunne Avenue
# Walsh Ave => Walsh Avenue
# Seaboard Ave => Seaboard Avenue
# Meridian Ave => Meridian Avenue
# Greenbriar Ave => Greenbriar Avenue
# The Alameda Ave => The Alameda Avenue
# Hollenbeck Ave => Hollenbeck Avenue
# W Washington Ave => W Washington Avenue
# Cherry Ave => Cherry Avenue
# El Paseo de Saratoga => El Paseo de Saratoga
# The Alameda => The Alameda
# Felton Way => Felton Way
# Embedded Way => Embedded Way
# Westlynn Way => Westlynn Way
# Tonita Way => Tonita Way
# Farmingham Way => Farmingham Way
# Blanchard Way => Blanchard Way
# Arata Way => Arata Way
# Hunter Way => Hunter Way
# John Way => John Way
# Revelstoke Way => Revelstoke Way
# Queensbridge Way => Queensbridge Way
# Devonshire Way => Devonshire Way
# Windsor Way => Windsor Way
# Primrose Way => Primrose Way
# Prince Edward Way => Prince Edward Way
# Flamingo Way => Flamingo Way
# Almaden Express Way => Almaden Express Way
# Mallard Way => Mallard Way
# Dunnock Way => Dunnock Way
# Danromas Way => Danromas Way
# Saich Way => Saich Way
# Longfellow Way => Longfellow Way
# Connemara Way => Connemara Way
# Humewick Way => Humewick Way
# Holger Way => Holger Way
# Normandy Way => Normandy Way
# Hermocilla Way => Hermocilla Way
# Erin Way => Erin Way
# Pyrus Way => Pyrus Way
# Sturgeon Way => Sturgeon Way
# Mandarin Way => Mandarin Way
# Locksunart Way => Locksunart Way
# Belfry Way => Belfry Way
# Albright Way => Albright Way
# Woz Way => Woz Way
# Zinfandel Way => Zinfandel Way
# Kingfisher Way => Kingfisher Way
# Ward Way => Ward Way
# Cisco Way => Cisco Way
# Allison Way => Allison Way
# Robindell Way => Robindell Way
# Willowbrook Way => Willowbrook Way
# Big Basin Way => Big Basin Way
# Nandina Way => Nandina Way
# Flicker Way => Flicker Way
# Terry Way => Terry Way
# Nelson Way => Nelson Way
# Moreland Way => Moreland Way
# Dublin Way => Dublin Way
# Hamilton Way => Hamilton Way
# Martinwood Way => Martinwood Way
# Firebird Way => Firebird Way
# Lilac Way => Lilac Way
# Patriot Way => Patriot Way
# Senate Way => Senate Way
# Alderbrook Way => Alderbrook Way
# Dorset Way => Dorset Way
# San Luisito Way => San Luisito Way
# Miette Way => Miette Way
# Milky Way => Milky Way
# Flin Way => Flin Way
# Whitney Way => Whitney Way
# Shelburne Way => Shelburne Way
# Carick Way & Ravens Place Way => Carick Way & Ravens Place Way
# Cheshire Way => Cheshire Way
# Gillick Way => Gillick Way
# Innovation Way => Innovation Way
# Candlelight Way => Candlelight Way
# Brahms Way => Brahms Way
# Ryland Park Way => Ryland Park Way
# Woodbank Way => Woodbank Way
# Ridgeview Way => Ridgeview Way
# Samson Way => Samson Way
# Tartarian Way => Tartarian Way
# Larry Way => Larry Way
# Wilson Way => Wilson Way
# Dial Way => Dial Way
# Squirewood Way => Squirewood Way
# Las Ondas Way => Las Ondas Way
# Duncardine Way => Duncardine Way
# Poppy Way => Poppy Way
# Aries Way => Aries Way
# San Luis Way => San Luis Way
# Durshire Way => Durshire Way
# Cartwright Way => Cartwright Way
# Barnsley Way => Barnsley Way
# Altair Way => Altair Way
# Enterprise Way => Enterprise Way
# Carlisle Way => Carlisle Way
# Marie P. DeBartolo Way => Marie P. DeBartolo Way
# Bianchi Way => Bianchi Way
# Wildflower Way => Wildflower Way
# Sakura Way => Sakura Way
# Tomlin Way => Tomlin Way
# Tangerine Way => Tangerine Way
# Colt Way => Colt Way
# Forge Way => Forge Way
# Berwick Way => Berwick Way
# All America Way => All America Way
# Serra Way => Serra Way
# Clifden Way => Clifden Way
# Dartshire Way => Dartshire Way
# Dunholme Way => Dunholme Way
# Dunford Way => Dunford Way
# Fife Way => Fife Way
# Epic Way => Epic Way
# Santa Teresa Blvd => Santa Teresa Boulevard
# Palm Valley Blvd => Palm Valley Boulevard
# Mission College Blvd => Mission College Boulevard
# N McCarthy Blvd => N McCarthy Boulevard
# McCarthy Blvd => McCarthy Boulevard
# Stevens Creek Blvd => Stevens Creek Boulevard
# Los Gatos Blvd => Los Gatos Boulevard
# Southwest Expressway => Southwest Expressway
# San Tomas Expressway => San Tomas Expressway
# Montague Expressway => Montague Expressway
# West Capitol Expressway => West Capitol Expressway
# East Capitol Expressway => East Capitol Expressway
# Almaden Expressway => Almaden Expressway
# Central Expressway => Central Expressway
# Lawrence Expressway => Lawrence Expressway
# Portal Plaza => Portal Plaza
# Rivermark Plaza => Rivermark Plaza
# Vanderbilt Court East => Vanderbilt Court East
# Rio Robles East => Rio Robles East
# Park Circle East => Park Circle East
# Monterey Hwy => Monterey Highway
# Hwy 17 PM 7.1 => Hwy 17 PM 7.1
# Mount Hamilton => Mount Hamilton
# Village View Loop => Village View Loop
# Infinite Loop => Infinite Loop
# Santana Row => Santana Row
# wilcox ave => wilcox Avenue
# Bellomy => Bellomy
# Amherst Terrace => Amherst Terrace
# Markham Terrace => Markham Terrace
# Windsor Terrace => Windsor Terrace
# Santa Rosalia Terrace => Santa Rosalia Terrace
# Costa Mesa Terrace => Costa Mesa Terrace
# Pine Pass Terrace => Pine Pass Terrace
# Pescadero Terrace => Pescadero Terrace
# Pyracantha Terrace => Pyracantha Terrace
# Spencer Terrace => Spencer Terrace
# Hobart Terrace => Hobart Terrace
# Avoset Terrace => Avoset Terrace
# Satsuma Terrace => Satsuma Terrace
# Yellowstone Terrace => Yellowstone Terrace
# Riorden Terrace => Riorden Terrace
# Belmont Terrace => Belmont Terrace
# Leuven Terrace => Leuven Terrace
# Holthouse Terrace => Holthouse Terrace
# Liege Terrace => Liege Terrace
# Redondo Terrace => Redondo Terrace
# Manet Terrace => Manet Terrace
# Miller Terrace => Miller Terrace
# Bridgeport Terrace => Bridgeport Terrace
# Springfield Terrace => Springfield Terrace
# Kearny Terrace => Kearny Terrace
# Brea Terrace => Brea Terrace
# Pismo Terrace => Pismo Terrace
# Fontana Terrace => Fontana Terrace
# Lessing Terrace => Lessing Terrace
# Raines Terrace => Raines Terrace
# Bristol Terrace => Bristol Terrace
# Cedarbrook Terrace => Cedarbrook Terrace
# Avon Terrace => Avon Terrace
# Hogarth Terrace => Hogarth Terrace
# Crown Point Terrace => Crown Point Terrace
# Karby Terrace => Karby Terrace
# Seneca Terrace => Seneca Terrace
# Lautrec Terrace => Lautrec Terrace
# Pennyroyal Terrace => Pennyroyal Terrace
# Pasito Terrace => Pasito Terrace
# Reston Terrace => Reston Terrace
# Panache Terrace => Panache Terrace
# Pinnacles Terrace => Pinnacles Terrace
# Isla Vista Terrace => Isla Vista Terrace
# Oak Point Terrace => Oak Point Terrace
# Anaheim Terrace => Anaheim Terrace
# Fountain Oaks Dr => Fountain Oaks Drive
# Linwood Dr => Linwood Drive
# Samaritan Dr => Samaritan Drive
# Minto Dr => Minto Drive
# Oakmead Village Dr => Oakmead Village Drive
# 1490 S Park Victoria Dr => 1490 S Park Victoria Drive
# 1350 S Park Victoria Dr => 1350 S Park Victoria Drive
# Blossom Hill => Blossom Hill
# Paseo de San Antonio Walk => Paseo de San Antonio Walk
# Quimby Rd => Quimby Road
# Berryessa Rd => Berryessa Road
# Silver Creek Valley Rd => Silver Creek Valley Road
# Wolfe Rd => Wolfe Road
# Mt. Hamilton Rd => Mt. Hamilton Road
# Mt Hamilton Rd => Mt Hamilton Road
# Homestead Rd => Homestead Road
# Saratoga Los Gatos Rd => Saratoga Los Gatos Road
# San Antonio Valley Rd => San Antonio Valley Road
# Perivale Ct => Perivale Court
# West Evelyn Avenue Suite #114 => West Evelyn Avenue Suite #114
# Franklin => Franklin
# N 5th St => N 5th Street
# Casa Verde St => Casa Verde Street
# Monroe St => Monroe Street
# Monterey Highway => Monterey Highway
# Old Santa Cruz Highway => Old Santa Cruz Highway
# Old Bayshore Highway => Old Bayshore Highway
# Paseo Presada => Paseo Presada
# Via Sorrento => Via Sorrento
# Via Volante => Via Volante
# Park Circle West => Park Circle West
# Vanderbilt Court West => Vanderbilt Court West
# Via del Oro => Via del Oro
# Great America Pkwy Ste 201 => Great America Pkwy Ste 201
# Terreno De Flores => Terreno De Flores
# Prospect Rd #1 => Prospect Rd #1
# Martin Avenue #6 => Martin Avenue #6
# Pruneridge Ave #6 => Pruneridge Ave #6
# Branham Ln => Branham Lane
# Barber Ln => Barber Lane
# Gaundabert Ln => Gaundabert Lane
# North Fair Oaks => North Fair Oaks
# Concourse Dr #81 => Concourse Dr #81
# Saratoga Avenue Bldg 4A => Saratoga Avenue Bldg 4A
# Franklin Mall => Franklin Mall
# Vista Montaña => Vista Montaña
# N 1st street => N 1st street
# Camina Esquela => Camina Esquela
# yes => yes
# Ala 680 PM 0.1 => Ala 680 PM 0.1
# S. Bascom => S. Bascom
# Winchester => Winchester
# Los Gatos Boulvevard => Los Gatos Boulvevard
# Broadway => Broadway
# Zanker Road, San Jose, CA => Zanker Road, San Jose, CA
# Zanker Rd., San Jose, CA => Zanker Rd., San Jose, CA
# Celadon Cir => Celadon Circle
# Calle de Luna => Calle de Luna
# Via San Marino => Via San Marino
# Via Napoli => Via Napoli
# Via Palamos => Via Palamos
# Via Portofino => Via Portofino
# Via Paviso => Via Paviso
# Calle de Barcelona => Calle de Barcelona
# Corte de Madrid => Corte de Madrid
# Corte de Seville => Corte de Seville
# Fountain Alley => Fountain Alley
# Cortona court => Cortona court
# Los Gatos Blvd. => Los Gatos Boulevard
# rio robles => rio robles
# West Julian => West Julian

# %%
## The following code is used to audit the zipcodes and improve them 
## The code can be found in audit_update_zipcodes.ipynb
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = 'des_moines.osm'
postal_code_re = re.compile(r'^[0-9]{5}?$')

def audit_zipcodes(osmfile):
    osm_file = open(osmfile, "r", encoding="utf8")
    postal_codes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)): # TODO: Learn about what events param does
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postal_codes(tag):
                    m = postal_code_re.search(tag.attrib['v'])
                    if m:
                        postal_codes['formatted'].add(m.group())
                    else:
                        postal_codes['not_formatted'].add(tag.attrib['v'])
                
    osm_file.close()
    return postal_codes


def is_postal_codes(elem):
    return (elem.attrib['k'] == "addr:postcode")

st_types = audit_zipcodes(OSMFILE)
pprint.pprint(dict(st_types))
# Out:
# {'formatted': {'50003',
#                '50009',
#                '50021',
#                '50023',
#                '50035',
#                '50047',
#                '50054',
#                '50061',
#                '50063',
#                '50111',
#                '50118',
#                '50131',
#                '50169',
#                '50211',
#                '50228',
#                '50237',
#                '50261',
#                '50263',
#                '50265',
#                '50266',
#                '50309',
#                '50310',
#                '50311',
#                '50312',
#                '50313',
#                '50314',
#                '50315',
#                '50316',
#                '50317',
#                '50319',
#                '50320',
#                '50321',
#                '50322',
#                '50323',
#                '50324',
#                '50325',
#                '50327'},
#  'not_formatted': {'50021-4021',
#                    '50021-9335',
#                    '50021-9353',
#                    '50023-3054',
#                    '50023-7235',
#                    '50023-9723',
#                    '50131-1824',
#                    '50265-2053',
#                    '50265-5318',
#                    '50311-4207',
#                    '50312-2099',
#                    '50313-1202',
#                    '50313-1206',
#                    '50313-2213',
#                    '50313-2712',
#                    '50313-2798',
#                    '50313-3431',
#                    '50313-4056',
#                    '50313-4155',
#                    '50313-4175',
#                    '50313-4237',
#                    '50313-4627'}}

# %%
import zipcodes
def update_zipcode(zipcode):
    #return re.sub('(\d{5})-\d{4}', '\\1', zipcode)
    #print(zipcode)
    b = re.findall(r'\d+', zipcode)
    if b: 
        return b[0]


    
st_types = audit_zipcodes(OSMFILE)

for st_type, ways in st_types.items(): # changed this method from .iteritems() from 2.7 to 3.6's .items()  
        for name in ways:
            better_name = update_zipcode(name)
            print (name, "=>", better_name)
# Out:
# 50261 => 50261
# 50211 => 50211
# 50315 => 50315
# 50035 => 50035
# 50320 => 50320
# 50054 => 50054
# 50021 => 50021
# 50325 => 50325
# 50237 => 50237
# 50324 => 50324
# 50321 => 50321
# 50316 => 50316
# 50047 => 50047
# 50061 => 50061
# 50009 => 50009
# 50111 => 50111
# 50263 => 50263
# 50319 => 50319
# 50314 => 50314
# 50310 => 50310
# 50311 => 50311
# 50327 => 50327
# 50322 => 50322
# 50309 => 50309
# 50266 => 50266
# 50317 => 50317
# 50228 => 50228
# 50312 => 50312
# 50323 => 50323
# 50063 => 50063
# 50265 => 50265
# 50118 => 50118
# 50169 => 50169
# 50313 => 50313
# 50003 => 50003
# 50131 => 50131
# 50023 => 50023
# 50313-2712 => 50313
# 50313-1202 => 50313
# 50021-9335 => 50021
# 50023-3054 => 50023
# 50313-4155 => 50313
# 50313-1206 => 50313
# 50313-2213 => 50313
# 50131-1824 => 50131
# 50313-4175 => 50313
# 50311-4207 => 50311
# 50312-2099 => 50312
# 50313-4627 => 50313
# 50021-9353 => 50021
# 50313-4237 => 50313
# 50265-5318 => 50265
# 50021-4021 => 50021
# 50023-7235 => 50023
# 50313-2798 => 50313
# 50023-9723 => 50023
# 50313-3431 => 50313
# 50265-2053 => 50265
# 50313-4056 => 50313

# %%
## The following code can be used to audit telephone numbers and improve them
## The code can be found in audit_update_telephone_numbers.ipynb
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

#OSMFILE = 'example.osm'
OSMFILE = 'des_moines.osm'
#telephone_re = re.compile(r'^(\d{3})-(\d{3})-(\d{4})$') 
telephone_re = re.compile(r'^\(\d{3}\)\s(\d{3})-(\d{4})$') 

def audit_phone_number(osmfile):
    osm_file = open(osmfile, "r", encoding="utf8")
    phone_numbers = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)): # TODO: Learn about what events param does
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_phone_number(tag):
                    m = telephone_re.search(tag.attrib['v'])
                    if m:
                        phone_numbers['correct'].add(m.group())
                    else:
                        phone_numbers['incorrect'].add(tag.attrib['v'])
    osm_file.close()
    return phone_numbers
    

def is_phone_number(elem):
    return (elem.attrib['k'] == "phone" or elem.attrib['k'] == "contact:phone")

#def update phone_number()
phone_types = audit_phone_number(OSMFILE)
pprint.pprint(dict(phone_types))
# Out:
# {'correct': {'(408) 238-2086',
#              '(408) 238-6000',
#              '(408) 238-7458',
#              '(408) 244-6851',
#              '(408) 244-9922',
#              '(408) 251-7693',
#              '(408) 258-4901',
#              '(408) 262-0401',
#              '(408) 262-0731',
#              '(408) 262-6727',
#              '(408) 263-2131',
#              '(408) 263-2318',
#              '(408) 263-3626',
#              '(408) 263-3900',
#              '(408) 264-9400',
#              '(408) 265-3392',
#              '(408) 269-1600',
#              '(408) 270-4964',
#              '(408) 270-6120',
#              '(408) 275-6916',
#              '(408) 277-4625',
#              '(408) 288-5679',
#              '(408) 292-2070',
#              '(408) 292-6494',
#              '(408) 294-4130',
#              '(408) 295-2000',
#              '(408) 295-7150',
#              '(408) 347-0990',
#              '(408) 354-1981',
#              '(408) 354-2128',
#              '(408) 354-2223',
#              '(408) 354-3524',
#              '(408) 354-4125',
#              '(408) 354-5808',
#              '(408) 354-5917',
#              '(408) 354-6446',
#              '(408) 354-6576',
#              '(408) 354-7365',
#              '(408) 354-7515',
#              '(408) 354-8920',
#              '(408) 395-2228',
#              '(408) 395-7800',
#              '(408) 395-9100',
#              '(408) 399-3931',
#              '(408) 399-9765',
#              '(408) 402-5965',
#              '(408) 462-9176',
#              '(408) 484-4315',
#              '(408) 493-6090',
#              '(408) 502-5087',
#              '(408) 510-0486',
#              '(408) 528-9160',
#              '(408) 532-9495',
#              '(408) 533-1107',
#              '(408) 564-7675',
#              '(408) 596-5885',
#              '(408) 629-2400',
#              '(408) 661-9803',
#              '(408) 730-5510',
#              '(408) 732-1573',
#              '(408) 732-8775',
#              '(408) 735-7800',
#              '(408) 738-3666',
#              '(408) 739-6588',
#              '(408) 741-1104',
#              '(408) 745-8000',
#              '(408) 765-5050',
#              '(408) 805-1755',
#              '(408) 830-0628',
#              '(408) 831-7797',
#              '(408) 885-1898',
#              '(408) 912-1712',
#              '(408) 915-2337',
#              '(408) 934-0304',
#              '(408) 934-1111',
#              '(408) 934-1533',
#              '(408) 943-3193',
#              '(408) 945-1331',
#              '(408) 946-5336',
#              '(408) 956-9410',
#              '(650) 603-8026',
#              '(669) 777-9035',
#              '(800) 951-3663',
#              '(855) 245-3663',
#              '(866) 287-7046'},
#  'incorrect': {'(1)(408) 766-7000',
#                '(408) 264 - 7333',
#                '(408) 399 -3444',
#                '(408)-252-5299',
#                '(408)-554-0852',
#                '(408)-732-0300',
#                '(408)224-3293',
#                '(408)370-6727',
#                '+ 408 980 6400',
#                '+1',
#                '+1 (408) 224-8600',
#                '+1 (408) 245-8434',
#                '+1 (408) 263-6855',
#                '+1 (408) 320-4660',
#                '+1 (408) 364-3700',
#                '+1 (408) 376-3516',
#                '+1 (408) 446-9000',
#                '+1 (408) 487-1000',
#                '+1 (408) 861-1000',
#                '+1 (408) 996-3444',
#                '+1 (800) 231-8676',
#                '+1 408 220 2200',
#                '+1 408 220 6588',
#                '+1 408 228 3700',
#                '+1 408 236 7395',
#                '+1 408 244 0900',
#                '+1 408 244 7311',
#                '+1 408 245 0014',
#                '+1 408 245 1745',
#                '+1 408 245 2253',
#                '+1 408 245 3276',
#                '+1 408 245 4100',
#                '+1 408 245 4350',
#                '+1 408 245 4571',
#                '+1 408 245 5554',
#                '+1 408 245 5722',
#                '+1 408 245 6888',
#                '+1 408 245 8500',
#                '+1 408 245 8585',
#                '+1 408 245 9500',
#                '+1 408 246 1484',
#                '+1 408 246 6320',
#                '+1 408 246 8800',
#                '+1 408 247 2101',
#                '+1 408 252 1019',
#                '+1 408 252-7885',
#                '+1 408 255 2166',
#                '+1 408 255 7576',
#                '+1 408 257 7000',
#                '+1 408 257-7550',
#                '+1 408 257-8877',
#                '+1 408 261 2199',
#                '+1 408 2626949',
#                '+1 408 266 8866',
#                '+1 408 269 3715',
#                '+1 408 2691048',
#                '+1 408 271 6840',
#                '+1 408 273 7000',
#                '+1 408 279 3222',
#                '+1 408 283 8100',
#                '+1 408 292 3798',
#                '+1 408 292 7030',
#                '+1 408 294 0252',
#                '+1 408 294 2244',
#                '+1 408 294 2558',
#                '+1 408 294 2677',
#                '+1 408 295 2911',
#                '+1 408 295 4200',
#                '+1 408 335 0042',
#                '+1 408 356 3281',
#                '+1 408 356 4665',
#                '+1 408 358 2000',
#                '+1 408 358 2774',
#                '+1 408 358 6042',
#                '+1 408 369 9078',
#                '+1 408 378 0622',
#                '+1 408 378 1935',
#                '+1 408 402 0604',
#                '+1 408 421 7699',
#                '+1 408 423 8044',
#                '+1 408 4358000',
#                '+1 408 452 1060',
#                '+1 408 453 1983',
#                '+1 408 453 6200',
#                '+1 408 467 2387',
#                '+1 408 470 3704',
#                '+1 408 477 2914',
#                '+1 408 477 8350',
#                '+1 408 482 1367',
#                '+1 408 492 9304',
#                '+1 408 496 0500',
#                '+1 408 498 7194',
#                '+1 408 530 0156',
#                '+1 408 543 5202',
#                '+1 408 554-6594',
#                '+1 408 576 7000',
#                '+1 408 588 0077',
#                '+1 408 596 5554',
#                '+1 408 601 1000',
#                '+1 408 606-5775',
#                '+1 408 617 1300',
#                '+1 408 642 1860',
#                '+1 408 645 7776',
#                '+1 408 685 2072',
#                '+1 408 685-2985',
#                '+1 408 707 2980',
#                '+1 408 720 0900',
#                '+1 408 727 7907',
#                '+1 408 730 1118',
#                '+1 408 730 1468',
#                '+1 408 730 7758',
#                '+1 408 732 3350',
#                '+1 408 732 3998',
#                '+1 408 732 4280',
#                '+1 408 732 6200',
#                '+1 408 732 9450',
#                '+1 408 733 1111',
#                '+1 408 733 1304',
#                '+1 408 733 1482',
#                '+1 408 733 2730',
#                '+1 408 733 6611',
#                '+1 408 733 7112',
#                '+1 408 7339000',
#                '+1 408 735 1619',
#                '+1 408 735 7182',
#                '+1 408 735 9300',
#                '+1 408 736 1315',
#                '+1 408 736 3726',
#                '+1 408 736 3746',
#                '+1 408 736 5590',
#                '+1 408 736 6859',
#                '+1 408 736 7573',
#                '+1 408 736 7588',
#                '+1 408 737 0711',
#                '+1 408 737 7376',
#                '+1 408 737 7791',
#                '+1 408 737 8587',
#                '+1 408 738 0330',
#                '+1 408 738 2500',
#                '+1 408 738 4862',
#                '+1 408 739 1282',
#                '+1 408 739 1798',
#                '+1 408 739 2084',
#                '+1 408 739 3545',
#                '+1 408 739 7717',
#                '+1 408 739 7771',
#                '+1 408 739 9011',
#                '+1 408 739 9248',
#                '+1 408 739 9525',
#                '+1 408 741-9642',
#                '+1 408 744-0485',
#                '+1 408 746 3020',
#                '+1 408 773 0200',
#                '+1 408 774 0595',
#                '+1 408 774 1889',
#                '+1 408 774 9015',
#                '+1 408 778 7373',
#                '+1 408 794 7297',
#                '+1 408 807 0792',
#                '+1 408 830 9100',
#                '+1 408 834 1527',
#                '+1 408 861 0881',
#                '+1 408 866 1222',
#                '+1 408 866-8264',
#                '+1 408 871 9042',
#                '+1 408 919 0088',
#                '+1 408 933 3608',
#                '+1 408 940 6284',
#                '+1 408 943 0250',
#                '+1 408 943 2600',
#                '+1 408 952 8200',
#                '+1 408 965 8000',
#                '+1 408 969 0887',
#                '+1 408 969 9900',
#                '+1 408 971 3977',
#                '+1 408 984 5395',
#                '+1 408 988 1883',
#                '+1 408 992 1004',
#                '+1 408 992 1020',
#                '+1 408 996 9131',
#                '+1 408 998 5774',
#                '+1 408-201-6300',
#                '+1 408-201-9200',
#                '+1 408-239-0107',
#                '+1 408-247-4300',
#                '+1 408-252-2200',
#                '+1 408-260-2727',
#                '+1 408-292-1212',
#                '+1 408-293-8810',
#                '+1 408-371-4611',
#                '+1 408-374-9090',
#                '+1 408-531-8204',
#                '+1 408-532-2944',
#                '+1 408-578-2912',
#                '+1 408-730-0511',
#                '+1 408-736-3418',
#                '+1 408-776-9221',
#                '+1 408-778-0551',
#                '+1 408-778-5077',
#                '+1 408-778-6409',
#                '+1 408-779-0244',
#                '+1 408-779-2211',
#                '+1 408-779-2925',
#                '+1 408-779-3200',
#                '+1 408-779-5650',
#                '+1 408-779-7259',
#                '+1 408-782-7806',
#                '+1 408-782-8201',
#                '+1 408-782-9591',
#                '+1 408-825-1000',
#                '+1 408-831-4000',
#                '+1 408-865-1992',
#                '+1 408-947-7000',
#                '+1 669 236 7534',
#                '+1 831 566 2382',
#                '+1 877 502-2837',
#                '+1 888 255 3637',
#                '+1-408 564-7346',
#                '+1-408-200-4868',
#                '+1-408-213-0810',
#                '+1-408-225-9888',
#                '+1-408-241-3801',
#                '+1-408-244-1968',
#                '+1-408-245-5330',
#                '+1-408-246-1010',
#                '+1-408-246-5251',
#                '+1-408-246-7580',
#                '+1-408-247-7333',
#                '+1-408-247-9998',
#                '+1-408-248-2838',
#                '+1-408-253-7167',
#                '+1-408-258-3261',
#                '+1-408-263-6788',
#                '+1-408-265-2600',
#                '+1-408-266-3230',
#                '+1-408-270-2900',
#                '+1-408-275-0389',
#                '+1-408-279-6000',
#                '+1-408-286-2729',
#                '+1-408-286-6275',
#                '+1-408-286-8808',
#                '+1-408-288-5339',
#                '+1-408-288-9172',
#                '+1-408-289-1510',
#                '+1-408-289-9508',
#                '+1-408-290-9660',
#                '+1-408-291-4553',
#                '+1-408-292-1404',
#                '+1-408-292-3177',
#                '+1-408-292-3333',
#                '+1-408-2926217',
#                '+1-408-294-2802',
#                '+1-408-294-3303;+1-408-998-9427',
#                '+1-408-295-0159',
#                '+1-408-295-3402',
#                '+1-408-295-3786',
#                '+1-408-295-5554',
#                '+1-408-295-6010',
#                '+1-408-298-9731',
#                '+1-408-321-8888',
#                '+1-408-326-2910',
#                '+1-408-330-0691',
#                '+1-408-343-1154',
#                '+1-408-346-2022',
#                '+1-408-354-9911',
#                '+1-408-371-9033',
#                '+1-408-380-4784',
#                '+1-408-383-3700',
#                '+1-408-399-6396',
#                '+1-408-418-4500',
#                '+1-408-423-8502',
#                '+1-408-434-1839',
#                '+1-408-440-0105',
#                '+1-408-441-0175',
#                '+1-408-441-1740',
#                '+1-408-463-0125',
#                '+1-408-470-8000',
#                '+1-408-481-9350',
#                '+1-408-486-9705',
#                '+1-408-501-0011',
#                '+1-408-526-0600',
#                '+1-408-530-9200',
#                '+1-408-547-5500',
#                '+1-408-554-8800',
#                '+1-408-567-9144',
#                '+1-408-577-2237',
#                '+1-408-588-4045',
#                '+1-408-598-7128',
#                '+1-408-626-3408',
#                '+1-408-629-5229',
#                '+1-408-637-7777',
#                '+1-408-642-1800',
#                '+1-408-654-9137',
#                '+1-408-654-9503',
#                '+1-408-654-9860',
#                '+1-408-720-8689',
#                '+1-408-727-1000',
#                '+1-408-727-1800',
#                '+1-408-729-7182',
#                '+1-408-733-1212',
#                '+1-408-738-3261',
#                '+1-408-739-4560',
#                '+1-408-743-5650',
#                '+1-408-746-9746',
#                '+1-408-777-3160',
#                '+1-408-777-8897',
#                '+1-408-794-7275',
#                '+1-408-844-9400',
#                '+1-408-855-3977',
#                '+1-408-861-3700',
#                '+1-408-864-0350',
#                '+1-408-920-0316',
#                '+1-408-922-7255',
#                '+1-408-922-9980',
#                '+1-408-942-8900',
#                '+1-408-946-2971',
#                '+1-408-946-8012',
#                '+1-408-946-8899',
#                '+1-408-947-0497',
#                '+1-408-947-2030',
#                '+1-408-947-3472',
#                '+1-408-955-0238',
#                '+1-408-956-1846',
#                '+1-408-957-9215',
#                '+1-408-969-0277',
#                '+1-408-971-1160',
#                '+1-408-971-2287',
#                '+1-408-971-8000',
#                '+1-408-975-9371',
#                '+1-408-977-0303',
#                '+1-408-986-8388',
#                '+1-408-988-3966',
#                '+1-408-988-5407',
#                '+1-408-988-8803',
#                '+1-480-956-8655',
#                '+1-800-673-9981',
#                '+1-800-7770133',
#                '+1-800-POLYCOM',
#                '+1-831-335-7992',
#                '+1-866-360-0061',
#                '+1-866-792-5905',
#                '+1-877-214-8628',
#                '+1-877-301-6442',
#                '+1-888-506-VOKE',
#                '+1.408.245.3686',
#                '+1.408.245.4712',
#                '+1.408.245.5090',
#                '+1.408.245.5300',
#                '+1.408.245.5432',
#                '+1.408.297.4707',
#                '+1.408.297.8421',
#                '+1.408.369.0575',
#                '+1.408.469.4992',
#                '+1.408.498.9775',
#                '+1.408.524.3580',
#                '+1.408.559.6900',
#                '+1.408.571.6000',
#                '+1.408.720.1677',
#                '+1.408.720.9393',
#                '+1.408.730.7100',
#                '+1.408.730.7300',
#                '+1.408.732.2200',
#                '+1.408.735.5937',
#                '+1.408.736.2630',
#                '+1.408.736.6688',
#                '+1.408.738.1916',
#                '+1.408.746.9583',
#                '+1.408.771.0909',
#                '+1.855.244.7491',
#                '+14082272273',
#                '+14082469119',
#                '+14082469550',
#                '+14082472790',
#                '+14082558787',
#                '+14082577400',
#                '+14082635526',
#                '+14082719504',
#                '+14082871900',
#                '+14082972930',
#                '+14082986666',
#                '+14084335199',
#                '+14084819383',
#                '+14085508240',
#                '+14085647360',
#                '+14086158533',
#                '+14086180991',
#                '+14087380408',
#                '+14088235502',
#                '+14088639999',
#                '+14089219989',
#                '+14089829040',
#                '+16502898186',
#                '+16693427776',
#                '1 408 2521797',
#                '1 408 353 0995',
#                '1 408 362-9767',
#                '1 408 732 4222',
#                '1 408 733 8473',
#                '1(408)224-2215',
#                '1-408-259-7574',
#                '1-408-262-7100',
#                '1-408-267-1288',
#                '1-408-269-2834',
#                '1-408-298-3880',
#                '1-408-330-0001',
#                '1-408-365-1888',
#                '1-408-746-5641',
#                '1-408-937-1852',
#                '1-408-996-1443',
#                '1.408.245.5620',
#                '1.408.736.0921',
#                '1.408.736.4500',
#                '1.408.736.5411',
#                '1.408.738.1960',
#                '1.408.747.0770',
#                '1408-251-6900',
#                '14082925961',
#                '2924779',
#                '408 245 8988',
#                '408 358 5895',
#                '408 997-1667',
#                '408-217-8841',
#                '408-225-0107',
#                '408-225-0200',
#                '408-257-1045',
#                '408-260-0404',
#                '408-260-2256',
#                '408-262-5588',
#                '408-262-9554',
#                '408-263-2252',
#                '408-264-1208',
#                '408-265-1570',
#                '408-267-2550',
#                '408-267-4691',
#                '408-269-2245',
#                '408-269-2345',
#                '408-269-3440',
#                '408-269-4782',
#                '408-269-8331',
#                '408-270-7646',
#                '408-277-0510',
#                '408-281-8288',
#                '408-288-5676',
#                '408-289-1698',
#                '408-292-3858',
#                '408-293-5494',
#                '408-294-3086',
#                '408-297-1100',
#                '408-354-6891',
#                '408-356-2191',
#                '408-356-5126',
#                '408-356-5856',
#                '408-363-1991',
#                '408-365-8839',
#                '408-377-0190',
#                '408-377-0432',
#                '408-384-4220',
#                '408-402-5053',
#                '408-402-5799',
#                '408-423-4300',
#                '408-436-0930',
#                '408-440-8116',
#                '408-448-9204',
#                '408-454-8459',
#                '408-486-9890',
#                '408-492-9055',
#                '408-496-6300',
#                '408-498-4293',
#                '408-513-8200',
#                '408-526-1999',
#                '408-564-7690',
#                '408-578-7729',
#                '408-629-5906',
#                '408-629-7775',
#                '408-660-2093',
#                '408-677-3826',
#                '408-720-8840',
#                '408-737-2020',
#                '408-749-9333',
#                '408-771-7088',
#                '408-780-7748',
#                '408-785-1774',
#                '408-827-4127',
#                '408-866-9991',
#                '408-929-8973',
#                '408-934-9888',
#                '408-935-6070',
#                '408-935-9888',
#                '408-945-6466',
#                '408-946-0888',
#                '408-946-8020',
#                '408-955-9992',
#                '408-963-6509',
#                '408-972-5861',
#                '408-975-9281',
#                '408-977-0605',
#                '408-977-1010',
#                '408-978-7666',
#                '408-979-9552',
#                '408-985-6370',
#                '408-988-8881',
#                '408.266.6342',
#                '408.395.6434',
#                '408.395.7650',
#                '408.542.9766',
#                '4082060164',
#                '4082436868',
#                '4082441800',
#                '4082446009',
#                '4082452020',
#                '4082454469',
#                '4082455720',
#                '4082457760',
#                '4082458392',
#                '4082458828',
#                '4082476443',
#                '4082491360',
#                '4082522423',
#                '4082531111',
#                '4082547722',
#                '4082602763',
#                '4082607005',
#                '4082828800',
#                '4082861412',
#                '4082938538',
#                '4082976698',
#                '4083219500',
#                '4083405916',
#                '4083641564',
#                '4083654265',
#                '4083839898',
#                '4084462411',
#                '4084463853',
#                '4084507990',
#                '4084533133',
#                '4084819432',
#                '4084869727',
#                '4084921415',
#                '4084961016',
#                '4085151007',
#                '4085308728',
#                '4085411900',
#                '4085429002',
#                '4085429027',
#                '4085579975',
#                '4085679899',
#                '4086168828',
#                '4086224838',
#                '4086540339',
#                '4086549000',
#                '4086578485',
#                '4087067979',
#                '4087200322',
#                '4087208226',
#                '4087208538',
#                '4087208654',
#                '4087271419',
#                '4087273971',
#                '4087305505',
#                '4087308578',
#                '4087309642',
#                '4087321475',
#                '4087321952',
#                '4087337733',
#                '4087340209',
#                '4087342035',
#                '4087342200',
#                '4087350335',
#                '4087351102',
#                '4087357448',
#                '4087358657',
#                '4087361114',
#                '4087362895',
#                '4087365100',
#                '4087367000',
#                '4087367299',
#                '4087369496',
#                '4087377100',
#                '4087377183',
#                '4087378812',
#                '4087382177',
#                '4087383766',
#                '4087386825',
#                '4087388515',
#                '4087388761',
#                '4087390316',
#                '4087395533',
#                '4087398844',
#                '4087398960',
#                '4087457372',
#                '4087469192',
#                '4087897614',
#                '4088300094',
#                '4088309594',
#                '4088309933',
#                '4088558777',
#                '4088650149',
#                '4088718765',
#                '4088851903',
#                '4089699778',
#                '4089703300',
#                '4089739985',
#                '4089809607',
#                '4089829600',
#                '4089868226',
#                '4089868821',
#                '4089882555',
#                '4089882982',
#                '4089888228',
#                '4089889100',
#                '4089919090',
#                '4089977727',
#                '480-874-8635',
#                '800-297-4804',
#                '800-715-5242',
#                '800-849-1271',
#                '8002328669',
#                '8008001914',
#                '877-959-3424',
#                '877.268.2574',
#                '888-467-3530',
#                '888-585-9978',
#                '8882624386',
#                '\u200e+1 408 279-4225',
#                '\u200e+1 408 292-4300'}}

# %%
import phonenumbers
def update_phone_number(phone_no):
    for match in phonenumbers.PhoneNumberMatcher(phone_no, "US"):
        return phonenumbers.format_number(match.number, phonenumbers.PhoneNumberFormat.NATIONAL)
OSMFILE = 'des_moines.osm'       
st_types = audit_phone_number(OSMFILE)

for st_type, ways in st_types.items(): # changed this method from .iteritems() from 2.7 to 3.6's .items()  
        for name in ways:
            better_name = update_phone_number(name)
            print (name, "=>", better_name)
# Out:
# +1 408 733 1482 => (408) 733-1482
# 4084961016 => (408) 496-1016
# +14088235502 => (408) 823-5502
# 4083654265 => (408) 365-4265
# +1 408 739 7717 => (408) 739-7717
# +1-408-922-7255 => (408) 922-7255
# +1-408-481-9350 => (408) 481-9350
# +1 408 252 1019 => (408) 252-1019
# +1 408-947-7000 => (408) 947-7000
# 4084533133 => (408) 453-3133
# +1-408-321-8888 => (408) 321-8888
# +1-408-294-2802 => (408) 294-2802
# 408-972-5861 => (408) 972-5861
# 408-963-6509 => (408) 963-6509
# 1-408-259-7574 => (408) 259-7574
# +1 408 482 1367 => (408) 482-1367
# +1 408 992 1004 => (408) 992-1004
# +1 408 943 0250 => (408) 943-0250
# 4087208226 => (408) 720-8226
# +14082469550 => (408) 246-9550
# 408-260-0404 => (408) 260-0404
# +1 408 830 9100 => (408) 830-9100
# 408-225-0107 => (408) 225-0107
# +1 408-201-9200 => (408) 201-9200
# 4087273971 => (408) 727-3971
# +1-408-295-6010 => (408) 295-6010
# +1 408 642 1860 => (408) 642-1860
# 4082454469 => (408) 245-4469
# +1.408.571.6000 => (408) 571-6000
# 408-402-5053 => (408) 402-5053
# 408-225-0200 => (408) 225-0200
# +1 408 739 9525 => (408) 739-9525
# +1-408-292-1404 => (408) 292-1404
# 4085429002 => (408) 542-9002
# 4087361114 => (408) 736-1114
# 4089919090 => (408) 991-9090
# +1.408.498.9775 => (408) 498-9775
# +1 408 292 3798 => (408) 292-3798
# +1 408 737 0711 => (408) 737-0711
# 4087358657 => (408) 735-8657
# +1 408-736-3418 => (408) 736-3418
# +1 408 746 3020 => (408) 746-3020
# (408)-732-0300 => (408) 732-0300
# 4087378812 => (408) 737-8812
# +1 408 423 8044 => (408) 423-8044
# 800-715-5242 => (800) 715-5242
# +1 408 358 2000 => (408) 358-2000
# 4085429027 => (408) 542-9027
# (408)224-3293 => (408) 224-3293
# 8002328669 => (800) 232-8669
# +1.408.245.5300 => (408) 245-5300
# 4082476443 => (408) 247-6443
# 4086549000 => (408) 654-9000
# +1 408 952 8200 => (408) 952-8200
# 408-827-4127 => (408) 827-4127
# +1-408-920-0316 => (408) 920-0316
# 4087067979 => (408) 706-7979
# +1 408 378 0622 => (408) 378-0622
# 408-978-7666 => (408) 978-7666
# +1-408-286-6275 => (408) 286-6275
# +1 408 866 1222 => (408) 866-1222
# +1-408-294-3303;+1-408-998-9427 => (408) 294-3303
# +1 408-865-1992 => (408) 865-1992
# +1-480-956-8655 => (480) 956-8655
# +1-408-423-8502 => (408) 423-8502
# +1-408-371-9033 => (408) 371-9033
# +1 408-779-7259 => (408) 779-7259
# +1 408 739 3545 => (408) 739-3545
# +1-408-971-8000 => (408) 971-8000
# +1-408-246-1010 => (408) 246-1010
# 408-356-5126 => (408) 356-5126
# 4087369496 => (408) 736-9496
# +1 408 421 7699 => (408) 421-7699
# +14082972930 => (408) 297-2930
# 408 358 5895 => (408) 358-5895
# 408-660-2093 => (408) 660-2093
# 408 997-1667 => (408) 997-1667
# +1 408 255 7576 => (408) 255-7576
# 4082938538 => (408) 293-8538
# 408.395.6434 => (408) 395-6434
# +1 408 737 7791 => (408) 737-7791
# 408-448-9204 => (408) 448-9204
# 408-946-0888 => (408) 946-0888
# +16502898186 => (650) 289-8186
# 4085308728 => (408) 530-8728
# +1-408-975-9371 => (408) 975-9371
# 4087398960 => (408) 739-8960
# +1-408-292-3177 => (408) 292-3177
# +1-408 564-7346 => (408) 564-7346
# +1 408 356 3281 => (408) 356-3281
# +1-866-360-0061 => (866) 360-0061
# +1 408 467 2387 => (408) 467-2387
# 4089977727 => (408) 997-7727
# 408-264-1208 => (408) 264-1208
# +1 408 257-7550 => (408) 257-7550
# 408-289-1698 => (408) 289-1698
# 4089882555 => (408) 988-2555
# 4082976698 => (408) 297-6698
# 4089882982 => (408) 988-2982
# +1-408-253-7167 => (408) 253-7167
# +1 408 245 8500 => (408) 245-8500
# 408-267-4691 => (408) 267-4691
# +1.408.245.3686 => (408) 245-3686
# 408-946-8020 => (408) 946-8020
# +1-408-343-1154 => (408) 343-1154
# +1 408 735 1619 => (408) 735-1619
# +1-408-969-0277 => (408) 969-0277
# 4082436868 => (408) 243-6868
# +1 408-778-6409 => (408) 778-6409
# 1408-251-6900 => (408) 251-6900
# 4084819432 => (408) 481-9432
# 4087365100 => (408) 736-5100
# 408-498-4293 => (408) 498-4293
# 4082602763 => (408) 260-2763
# +1 408 294 2244 => (408) 294-2244
# +14086158533 => (408) 615-8533
# +1-800-673-9981 => (800) 673-9981
# +1 408-531-8204 => (408) 531-8204
# 408-294-3086 => (408) 294-3086
# +16693427776 => (669) 342-7776
# +14082577400 => (408) 257-7400
# 4087340209 => (408) 734-0209
# 4089809607 => (408) 980-9607
# +1 408 736 3746 => (408) 736-3746
# +1-408-470-8000 => (408) 470-8000
# ‎+1 408 292-4300 => (408) 292-4300
# 408-749-9333 => (408) 749-9333
# 4084921415 => (408) 492-1415
# +1-408-956-1846 => (408) 956-1846
# 877.268.2574 => (877) 268-2574
# 1 408 2521797 => (408) 252-1797
# +1-408-986-8388 => (408) 986-8388
# +1 408 739 2084 => (408) 739-2084
# +1-408-463-0125 => (408) 463-0125
# +1.408.730.7300 => (408) 730-7300
# 408-955-9992 => (408) 955-9992
# +1-408-279-6000 => (408) 279-6000
# 4087469192 => (408) 746-9192
# +1-877-214-8628 => (877) 214-8628
# +1-408-295-0159 => (408) 295-0159
# +1 408 554-6594 => (408) 554-6594
# 4087308578 => (408) 730-8578
# 408-269-2345 => (408) 269-2345
# +1-408-861-3700 => (408) 861-3700
# +1 408 588 0077 => (408) 588-0077
# 1-408-262-7100 => (408) 262-7100
# +1 408 257 7000 => (408) 257-7000
# 4082458392 => (408) 245-8392
# +1 408 245 5554 => (408) 245-5554
# 408-935-6070 => (408) 935-6070
# 408-384-4220 => (408) 384-4220
# +1-408-588-4045 => (408) 588-4045
# +1-408-383-3700 => (408) 383-3700
# +1 408 295 2911 => (408) 295-2911
# +1.408.746.9583 => (408) 746-9583
# +1-408-946-8012 => (408) 946-8012
# +1 408 720 0900 => (408) 720-0900
# 4088851903 => (408) 885-1903
# +1-866-792-5905 => (866) 792-5905
# +1-800-POLYCOM => None
# +1 408 498 7194 => (408) 498-7194
# +14089219989 => (408) 921-9989
# 408-277-0510 => (408) 277-0510
# 4082828800 => (408) 282-8800
# 408-578-7729 => (408) 578-7729
# +1-408-977-0303 => (408) 977-0303
# +1-408-598-7128 => (408) 598-7128
# +1 408 369 9078 => (408) 369-9078
# +1 408 733 7112 => (408) 733-7112
# 408-454-8459 => (408) 454-8459
# +1 408 606-5775 => (408) 606-5775
# +1 408 453 6200 => (408) 453-6200
# +1 408 576 7000 => (408) 576-7000
# 4082441800 => (408) 244-1800
# 408-363-1991 => (408) 363-1991
# +1 408 294 2677 => (408) 294-2677
# 4084463853 => (408) 446-3853
# +1-408-777-8897 => (408) 777-8897
# +1 408 358 2774 => (408) 358-2774
# +1-408-777-3160 => (408) 777-3160
# 877-959-3424 => (877) 959-3424
# +14088639999 => (408) 863-9999
# +14082469119 => (408) 246-9119
# +1-408-567-9144 => (408) 567-9144
# +1 408 738 0330 => (408) 738-0330
# +1 408 732 4280 => (408) 732-4280
# 4086224838 => (408) 622-4838
# +1 408 736 7588 => (408) 736-7588
# 4082458828 => (408) 245-8828
# +1 (408) 376-3516 => (408) 376-3516
# +1.855.244.7491 => (855) 244-7491
# 408-269-8331 => (408) 269-8331
# + 408 980 6400 => None
# 4087457372 => (408) 745-7372
# +1.408.720.1677 => (408) 720-1677
# 408-267-2550 => (408) 267-2550
# 1-408-937-1852 => (408) 937-1852
# 14082925961 => (408) 292-5961
# 4087309642 => (408) 730-9642
# 4083219500 => (408) 321-9500
# +1 408 735 7182 => (408) 735-7182
# +1-408-720-8689 => (408) 720-8689
# 1 408 733 8473 => (408) 733-8473
# +1 (408) 320-4660 => (408) 320-4660
# +1 408 732 9450 => (408) 732-9450
# +1-408-346-2022 => (408) 346-2022
# +14087380408 => (408) 738-0408
# +1 408 739 7771 => (408) 739-7771
# +1-408-290-9660 => (408) 290-9660
# 2924779 => None
# +1-408-577-2237 => (408) 577-2237
# (408)-554-0852 => (408) 554-0852
# 408-975-9281 => (408) 975-9281
# +1-408-291-4553 => (408) 291-4553
# +1-408-946-2971 => (408) 946-2971
# +1-408-922-9980 => (408) 922-9980
# +1-408-354-9911 => (408) 354-9911
# 4087321952 => (408) 732-1952
# 408-297-1100 => (408) 297-1100
# +1 408 220 2200 => (408) 220-2200
# +1 408 245 4100 => (408) 245-4100
# 408-629-5906 => (408) 629-5906
# +1 408-779-3200 => (408) 779-3200
# +1 408 261 2199 => (408) 261-2199
# 1-408-365-1888 => (408) 365-1888
# +1 408 736 5590 => (408) 736-5590
# +1 408 774 0595 => (408) 774-0595
# +1 408 245 5722 => (408) 245-5722
# 408-262-9554 => (408) 262-9554
# +1 408 246 8800 => (408) 246-8800
# 4082060164 => (408) 206-0164
# 4082607005 => (408) 260-7005
# +1-408-270-2900 => (408) 270-2900
# 408-929-8973 => (408) 929-8973
# 4084869727 => (408) 486-9727
# +1 408 271 6840 => (408) 271-6840
# +14089829040 => (408) 982-9040
# 4085679899 => (408) 567-9899
# +1 408 773 0200 => (408) 773-0200
# 1 408 362-9767 => (408) 362-9767
# 4087305505 => (408) 730-5505
# +1 408-252-2200 => (408) 252-2200
# 4087208654 => (408) 720-8654
# 4084462411 => (408) 446-2411
# +1-408-288-5339 => (408) 288-5339
# +1 408 294 0252 => (408) 294-0252
# +1.408.736.2630 => (408) 736-2630
# 408-281-8288 => (408) 281-8288
# +1 408 245 8585 => (408) 245-8585
# +14085647360 => (408) 564-7360
# +14082719504 => (408) 271-9504
# +1-408-247-9998 => (408) 247-9998
# +1 408 992 1020 => (408) 992-1020
# 408-293-5494 => (408) 293-5494
# 408-440-8116 => (408) 440-8116
# 4088309933 => (408) 830-9933
# 1-408-298-3880 => (408) 298-3880
# 408-365-8839 => (408) 365-8839
# 1-408-269-2834 => (408) 269-2834
# 4089829600 => (408) 982-9600
# +1.408.730.7100 => (408) 730-7100
# +1 408 988 1883 => (408) 988-1883
# +1 (408) 446-9000 => (408) 446-9000
# +1 408 866-8264 => (408) 866-8264
# +14082635526 => (408) 263-5526
# +1 408 971 3977 => (408) 971-3977
# (408)370-6727 => (408) 370-6727
# +1 408-779-2211 => (408) 779-2211
# +1 (800) 231-8676 => (800) 231-8676
# +1 408 871 9042 => (408) 871-9042
# 408-988-8881 => (408) 988-8881
# +1 408-778-0551 => (408) 778-0551
# +1 408 730 7758 => (408) 730-7758
# 408-629-7775 => (408) 629-7775
# +1-408-844-9400 => (408) 844-9400
# +1-408-988-5407 => (408) 988-5407
# 4089739985 => (408) 973-9985
# +1 408 738 2500 => (408) 738-2500
# +1 408 543 5202 => (408) 543-5202
# 4082491360 => (408) 249-1360
# 408.542.9766 => (408) 542-9766
# +14082472790 => (408) 247-2790
# 4089868226 => (408) 986-8226
# +1-408-247-7333 => (408) 247-7333
# +1 408 739 1282 => (408) 739-1282
# 4082547722 => (408) 254-7722
# +1-408-440-0105 => (408) 440-0105
# 408-270-7646 => (408) 270-7646
# +1-408-225-9888 => (408) 225-9888
# 4089889100 => (408) 988-9100
# +1 408 736 7573 => (408) 736-7573
# +1.408.559.6900 => (408) 559-6900
# +1-408-526-0600 => (408) 526-0600
# +1-408-530-9200 => (408) 530-9200
# +1-408-947-2030 => (408) 947-2030
# 1.408.736.0921 => (408) 736-0921
# +1-408-729-7182 => (408) 729-7182
# +1 408 730 1468 => (408) 730-1468
# +1-408-738-3261 => (408) 738-3261
# 4082452020 => (408) 245-2020
# 4089868821 => (408) 986-8821
# +1 408 247 2101 => (408) 247-2101
# +1 877 502-2837 => (877) 502-2837
# 1-408-996-1443 => (408) 996-1443
# (408) 264 - 7333 => (408) 264-7333
# +1-408-241-3801 => (408) 241-3801
# 408-265-1570 => (408) 265-1570
# 4089703300 => (408) 970-3300
# +1 408 940 6284 => (408) 940-6284
# +1-408-743-5650 => (408) 743-5650
# +1-408-263-6788 => (408) 263-6788
# +14082558787 => (408) 255-8787
# +1 408 617 1300 => (408) 617-1300
# 4084507990 => (408) 450-7990
# +1 408 245 0014 => (408) 245-0014
# 4087321475 => (408) 732-1475
# +1-408-292-3333 => (408) 292-3333
# +1-408-434-1839 => (408) 434-1839
# +1 408-201-6300 => (408) 201-6300
# (408) 399 -3444 => (408) 399-3444
# +1 => None
# +1 669 236 7534 => (669) 236-7534
# +1-408-501-0011 => (408) 501-0011
# 408-486-9890 => (408) 486-9890
# 408-260-2256 => (408) 260-2256
# +1.408.245.4712 => (408) 245-4712
# 4087271419 => (408) 727-1419
# +1 408 257-8877 => (408) 257-8877
# 4083641564 => (408) 364-1564
# 4088558777 => (408) 855-8777
# +1 408 741-9642 => (408) 741-9642
# +1 408 919 0088 => (408) 919-0088
# +1-408-266-3230 => (408) 266-3230
# 4087398844 => (408) 739-8844
# +1 408 530 0156 => (408) 530-0156
# +1 408 7339000 => (408) 733-9000
# 408-269-2245 => (408) 269-2245
# +1 408 738 4862 => (408) 738-4862
# 408-354-6891 => (408) 354-6891
# +1 408 736 6859 => (408) 736-6859
# 4087337733 => (408) 733-7733
# 408-288-5676 => (408) 288-5676
# +1 408 984 5395 => (408) 984-5395
# 1.408.736.4500 => (408) 736-4500
# +1 408-825-1000 => (408) 825-1000
# +1-408-399-6396 => (408) 399-6396
# +1 408 735 9300 => (408) 735-9300
# +1 408-293-8810 => (408) 293-8810
# +1 408-782-7806 => (408) 782-7806
# 4086540339 => (408) 654-0339
# +1-408-642-1800 => (408) 642-1800
# +1-408-295-3786 => (408) 295-3786
# 4087208538 => (408) 720-8538
# +1 408 737 8587 => (408) 737-8587
# 408-771-7088 => (408) 771-7088
# 1-408-267-1288 => (408) 267-1288
# +1 408 245 6888 => (408) 245-6888
# 1-408-746-5641 => (408) 746-5641
# +1-408-955-0238 => (408) 955-0238
# 408.266.6342 => (408) 266-6342
# +1-408-947-3472 => (408) 947-3472
# 4087383766 => (408) 738-3766
# +1 408 732 6200 => (408) 732-6200
# +1-408-246-7580 => (408) 246-7580
# +1 408 220 6588 => (408) 220-6588
# +1 408 252-7885 => (408) 252-7885
# +1 408 685-2985 => (408) 685-2985
# 408-866-9991 => (408) 866-9991
# 4089699778 => (408) 969-9778
# +1-408-486-9705 => (408) 486-9705
# +1 408 4358000 => (408) 435-8000
# 408-217-8841 => (408) 217-8841
# +1.408.245.5090 => (408) 245-5090
# +1-408-330-0691 => (408) 330-0691
# +1 408 245 4571 => (408) 245-4571
# +1-888-506-VOKE => None
# 4086578485 => (408) 657-8485
# +1 408 794 7297 => (408) 794-7297
# +1 408 228 3700 => (408) 228-3700
# +1.408.297.8421 => (408) 297-8421
# 4082455720 => (408) 245-5720
# +1 408 707 2980 => (408) 707-2980
# +1 408-292-1212 => (408) 292-1212
# 4087377183 => (408) 737-7183
# +1.408.720.9393 => (408) 720-9393
# 4082446009 => (408) 244-6009
# +1-408-275-0389 => (408) 275-0389
# +1 408 933 3608 => (408) 933-3608
# +14085508240 => (408) 550-8240
# +1 408 356 4665 => (408) 356-4665
# +1 408 778 7373 => (408) 778-7373
# +1 408 477 8350 => (408) 477-8350
# +1 408 732 3998 => (408) 732-3998
# +1-408-248-2838 => (408) 248-2838
# +1.408.732.2200 => (408) 732-2200
# +1-408-629-5229 => (408) 629-5229
# 4087342035 => (408) 734-2035
# +1 408 453 1983 => (408) 453-1983
# +1 408 739 1798 => (408) 739-1798
# 408-985-6370 => (408) 985-6370
# +1 408 739 9011 => (408) 739-9011
# 408-263-2252 => (408) 263-2252
# 1(408)224-2215 => (408) 224-2215
# +1 408 733 1111 => (408) 733-1111
# 408.395.7650 => (408) 395-7650
# +1 408 292 7030 => (408) 292-7030
# +1-408-288-9172 => (408) 288-9172
# +1 408-782-9591 => (408) 782-9591
# +1-408-265-2600 => (408) 265-2600
# +1 408 245 9500 => (408) 245-9500
# +1 (408) 245-8434 => (408) 245-8434
# +1-408-864-0350 => (408) 864-0350
# +1-408-213-0810 => (408) 213-0810
# +1-408-286-8808 => (408) 286-8808
# 4088309594 => (408) 830-9594
# 408-934-9888 => (408) 934-9888
# +1.408.524.3580 => (408) 524-3580
# +1 408 965 8000 => (408) 965-8000
# +1 408 492 9304 => (408) 492-9304
# +1-408-200-4868 => (408) 200-4868
# +1 408 730 1118 => (408) 730-1118
# +1.408.297.4707 => (408) 297-4707
# +1-408-739-4560 => (408) 739-4560
# 408-935-9888 => (408) 935-9888
# +1 408 245 2253 => (408) 245-2253
# 4087350335 => (408) 735-0335
# 408-492-9055 => (408) 492-9055
# 408-257-1045 => (408) 257-1045
# +1 408-831-4000 => (408) 831-4000
# +1-408-244-1968 => (408) 244-1968
# 4087390316 => (408) 739-0316
# +1 408-532-2944 => (408) 532-2944
# +1-408-794-7275 => (408) 794-7275
# +1 408 245 3276 => (408) 245-3276
# +1 408 969 0887 => (408) 969-0887
# +14084819383 => (408) 481-9383
# 4087377100 => (408) 737-7100
# 4087388761 => (408) 738-8761
# +1 408-779-5650 => (408) 779-5650
# +1 (408) 224-8600 => (408) 224-8600
# 4089888228 => (408) 988-8228
# 408-526-1999 => (408) 526-1999
# +1 (408) 487-1000 => (408) 487-1000
# +1 408 596 5554 => (408) 596-5554
# +1-408-947-0497 => (408) 947-0497
# 1 408 353 0995 => (408) 353-0995
# 408-402-5799 => (408) 402-5799
# 408-513-8200 => (408) 513-8200
# +1 408 733 6611 => (408) 733-6611
# 408-737-2020 => (408) 737-2020
# +1 888 255 3637 => (888) 255-3637
# +1-408-441-1740 => (408) 441-1740
# (1)(408) 766-7000 => (408) 766-7000
# 4082457760 => (408) 245-7760
# 800-297-4804 => (800) 297-4804
# +1.408.369.0575 => (408) 369-0575
# +1-408-654-9503 => (408) 654-9503
# 4087362895 => (408) 736-2895
# +1 408-371-4611 => (408) 371-4611
# +1 408 477 2914 => (408) 477-2914
# +1-408-746-9746 => (408) 746-9746
# 4083839898 => (408) 383-9898
# +14084335199 => (408) 433-5199
# 408-720-8840 => (408) 720-8840
# +1 408-374-9090 => (408) 374-9090
# +1 408-779-0244 => (408) 779-0244
# +1 408 246 6320 => (408) 246-6320
# +1 408 774 9015 => (408) 774-9015
# +1 408 774 1889 => (408) 774-1889
# +1-408-727-1000 => (408) 727-1000
# 4087342200 => (408) 734-2200
# +1 408 378 1935 => (408) 378-1935
# +1 408-730-0511 => (408) 730-0511
# +1 408 244 7311 => (408) 244-7311
# +1 408 335 0042 => (408) 335-0042
# +1 408 969 9900 => (408) 969-9900
# 4087382177 => (408) 738-2177
# 4087388515 => (408) 738-8515
# +1 408 601 1000 => (408) 601-1000
# +1-408-258-3261 => (408) 258-3261
# +1 408-247-4300 => (408) 247-4300
# 888-467-3530 => (888) 467-3530
# 408-496-6300 => (408) 496-6300
# 4083405916 => (408) 340-5916
# +1-408-855-3977 => (408) 855-3977
# +1-408-733-1212 => (408) 733-1212
# 408-977-0605 => (408) 977-0605
# +1 408-776-9221 => (408) 776-9221
# 408-292-3858 => (408) 292-3858
# +1-408-957-9215 => (408) 957-9215
# +1-408-298-9731 => (408) 298-9731
# 1 408 732 4222 => (408) 732-4222
# +1 (408) 996-3444 => (408) 996-3444
# +1-408-946-8899 => (408) 946-8899
# +1 408 452 1060 => (408) 452-1060
# +1 408 807 0792 => (408) 807-0792
# +1 408 733 2730 => (408) 733-2730
# 408-780-7748 => (408) 780-7748
# +1 408 269 3715 => (408) 269-3715
# +1-800-7770133 => (800) 777-0133
# +1 408 245 1745 => (408) 245-1745
# +1-408-245-5330 => (408) 245-5330
# +1-831-335-7992 => (831) 335-7992
# +1 408 2626949 => (408) 262-6949
# +1 408 266 8866 => (408) 266-8866
# 4087200322 => (408) 720-0322
# +1 408 496 0500 => (408) 496-0500
# 4088300094 => (408) 830-0094
# 4087367299 => (408) 736-7299
# +1 408 732 3350 => (408) 732-3350
# +1 408 998 5774 => (408) 998-5774
# +1 408 733 1304 => (408) 733-1304
# 8008001914 => (800) 800-1914
# 4087351102 => (408) 735-1102
# +1-408-286-2729 => (408) 286-2729
# +1-408-637-7777 => (408) 637-7777
# 408-677-3826 => (408) 677-3826
# 4082531111 => (408) 253-1111
# +1-408-289-9508 => (408) 289-9508
# +1 408 2691048 => (408) 269-1048
# +1 408 295 4200 => (408) 295-4200
# +1 408 236 7395 => (408) 236-7395
# 4088718765 => (408) 871-8765
# 8882624386 => (888) 262-4386
# +1 408 739 9248 => (408) 739-9248
# +1 408-779-2925 => (408) 779-2925
# +1 408 727 7907 => (408) 727-7907
# +1-408-971-1160 => (408) 971-1160
# 4087897614 => (408) 789-7614
# 408-979-9552 => (408) 979-9552
# 408-356-2191 => (408) 356-2191
# 1.408.245.5620 => (408) 245-5620
# +1 (408) 861-1000 => (408) 861-1000
# +1-408-380-4784 => (408) 380-4784
# +14082272273 => (408) 227-2273
# +1 408 255 2166 => (408) 255-2166
# +1-408-654-9860 => (408) 654-9860
# +1-408-654-9137 => (408) 654-9137
# 408-945-6466 => (408) 945-6466
# +1 408 737 7376 => (408) 737-7376
# +1-408-988-8803 => (408) 988-8803
# +14082871900 => (408) 287-1900
# 408-269-3440 => (408) 269-3440
# 408-785-1774 => (408) 785-1774
# 408-423-4300 => (408) 423-4300
# +1 408 279 3222 => (408) 279-3222
# 408-377-0190 => (408) 377-0190
# +1.408.735.5937 => (408) 735-5937
# 4082861412 => (408) 286-1412
# +1 408 470 3704 => (408) 470-3704
# +1.408.738.1916 => (408) 738-1916
# +14082986666 => (408) 298-6666
# +1 408 744-0485 => (408) 744-0485
# +1 831 566 2382 => (831) 566-2382
# +1-408-626-3408 => (408) 626-3408
# +1 408 244 0900 => (408) 244-0900
# +1 (408) 364-3700 => (408) 364-3700
# +1 408 358 6042 => (408) 358-6042
# 888-585-9978 => (888) 585-9978
# +1-408-554-8800 => (408) 554-8800
# +1 408-778-5077 => (408) 778-5077
# +1-408-441-0175 => (408) 441-0175
# 4087386825 => (408) 738-6825
# 1-408-330-0001 => (408) 330-0001
# 4087357448 => (408) 735-7448
# +1-408-246-5251 => (408) 246-5251
# +1-408-295-5554 => (408) 295-5554
# 4087395533 => (408) 739-5533
# +1 408 294 2558 => (408) 294-2558
# 408-356-5856 => (408) 356-5856
# 4085151007 => (408) 515-1007
# (408)-252-5299 => (408) 252-5299
# +1 408-578-2912 => (408) 578-2912
# 1.408.736.5411 => (408) 736-5411
# +1 408 943 2600 => (408) 943-2600
# +1 408 736 1315 => (408) 736-1315
# 1.408.747.0770 => (408) 747-0770
# +1.408.469.4992 => (408) 469-4992
# +1-877-301-6442 => (877) 301-6442
# +1 408 245 4350 => (408) 245-4350
# +1-408-418-4500 => (408) 418-4500
# +1-408-547-5500 => (408) 547-5500
# 4085579975 => (408) 557-9975
# 4082522423 => (408) 252-2423
# +1 408 996 9131 => (408) 996-9131
# +1 408 685 2072 => (408) 685-2072
# +1-408-289-1510 => (408) 289-1510
# 1.408.738.1960 => (408) 738-1960
# 4085411900 => (408) 541-1900
# 408-564-7690 => (408) 564-7690
# +1-408-326-2910 => (408) 326-2910
# +1-408-727-1800 => (408) 727-1800
# 408-269-4782 => (408) 269-4782
# +1 408 645 7776 => (408) 645-7776
# +1 408 246 1484 => (408) 246-1484
# +1-408-971-2287 => (408) 971-2287
# 408 245 8988 => (408) 245-8988
# +1 408 736 3726 => (408) 736-3726
# 480-874-8635 => (480) 874-8635
# ‎+1 408 279-4225 => (408) 279-4225
# +14086180991 => (408) 618-0991
# 4086168828 => (408) 616-8828
# 408-436-0930 => (408) 436-0930
# +1-408-942-8900 => (408) 942-8900
# 408-377-0432 => (408) 377-0432
# +1-408-988-3966 => (408) 988-3966
# +1 408 273 7000 => (408) 273-7000
# +1 (408) 263-6855 => (408) 263-6855
# +1.408.771.0909 => (408) 771-0909
# +1 408-260-2727 => (408) 260-2727
# +1 408-239-0107 => (408) 239-0107
# 408-262-5588 => (408) 262-5588
# 800-849-1271 => (800) 849-1271
# 4087367000 => (408) 736-7000
# +1 408 402 0604 => (408) 402-0604
# +1.408.736.6688 => (408) 736-6688
# +1-408-2926217 => (408) 292-6217
# +1 408-782-8201 => (408) 782-8201
# +1 408 834 1527 => (408) 834-1527
# +1-408-295-3402 => (408) 295-3402
# +1 408 861 0881 => (408) 861-0881
# 408-977-1010 => (408) 977-1010
# +1.408.245.5432 => (408) 245-5432
# +1 408 283 8100 => (408) 283-8100
# 4088650149 => (408) 865-0149
# (408) 292-6494 => (408) 292-6494
# (408) 251-7693 => (408) 251-7693
# (408) 765-5050 => (408) 765-5050
# (408) 263-2131 => (408) 263-2131
# (408) 738-3666 => (408) 738-3666
# (408) 270-4964 => (408) 270-4964
# (408) 354-4125 => (408) 354-4125
# (408) 502-5087 => (408) 502-5087
# (800) 951-3663 => (800) 951-3663
# (408) 238-6000 => (408) 238-6000
# (408) 532-9495 => (408) 532-9495
# (669) 777-9035 => (669) 777-9035
# (408) 741-1104 => (408) 741-1104
# (408) 528-9160 => (408) 528-9160
# (408) 735-7800 => (408) 735-7800
# (408) 732-8775 => (408) 732-8775
# (408) 263-3900 => (408) 263-3900
# (408) 915-2337 => (408) 915-2337
# (408) 564-7675 => (408) 564-7675
# (408) 294-4130 => (408) 294-4130
# (408) 354-8920 => (408) 354-8920
# (408) 354-7365 => (408) 354-7365
# (408) 399-3931 => (408) 399-3931
# (408) 277-4625 => (408) 277-4625
# (408) 943-3193 => (408) 943-3193
# (408) 258-4901 => (408) 258-4901
# (408) 533-1107 => (408) 533-1107
# (408) 295-7150 => (408) 295-7150
# (408) 354-5917 => (408) 354-5917
# (408) 354-1981 => (408) 354-1981
# (408) 730-5510 => (408) 730-5510
# (408) 805-1755 => (408) 805-1755
# (408) 354-5808 => (408) 354-5808
# (408) 263-2318 => (408) 263-2318
# (408) 262-0731 => (408) 262-0731
# (408) 264-9400 => (408) 264-9400
# (408) 238-2086 => (408) 238-2086
# (408) 732-1573 => (408) 732-1573
# (408) 354-3524 => (408) 354-3524
# (408) 946-5336 => (408) 946-5336
# (408) 462-9176 => (408) 462-9176
# (408) 510-0486 => (408) 510-0486
# (408) 934-1111 => (408) 934-1111
# (408) 269-1600 => (408) 269-1600
# (408) 745-8000 => (408) 745-8000
# (408) 395-7800 => (408) 395-7800
# (408) 288-5679 => (408) 288-5679
# (408) 956-9410 => (408) 956-9410
# (408) 354-2223 => (408) 354-2223
# (408) 244-6851 => (408) 244-6851
# (408) 292-2070 => (408) 292-2070
# (408) 262-0401 => (408) 262-0401
# (855) 245-3663 => (855) 245-3663
# (408) 934-1533 => (408) 934-1533
# (408) 395-2228 => (408) 395-2228
# (408) 885-1898 => (408) 885-1898
# (408) 354-2128 => (408) 354-2128
# (408) 402-5965 => (408) 402-5965
# (408) 295-2000 => (408) 295-2000
# (408) 945-1331 => (408) 945-1331
# (408) 238-7458 => (408) 238-7458
# (408) 270-6120 => (408) 270-6120
# (408) 484-4315 => (408) 484-4315
# (408) 262-6727 => (408) 262-6727
# (408) 934-0304 => (408) 934-0304
# (408) 912-1712 => (408) 912-1712
# (408) 399-9765 => (408) 399-9765
# (408) 354-7515 => (408) 354-7515
# (650) 603-8026 => (650) 603-8026
# (408) 830-0628 => (408) 830-0628
# (408) 354-6446 => (408) 354-6446
# (408) 596-5885 => (408) 596-5885
# (408) 244-9922 => (408) 244-9922
# (408) 395-9100 => (408) 395-9100
# (408) 265-3392 => (408) 265-3392
# (408) 629-2400 => (408) 629-2400
# (408) 661-9803 => (408) 661-9803
# (408) 263-3626 => (408) 263-3626
# (408) 739-6588 => (408) 739-6588
# (408) 493-6090 => (408) 493-6090
# (408) 275-6916 => (408) 275-6916
# (408) 831-7797 => (408) 831-7797
# (408) 354-6576 => (408) 354-6576
# (866) 287-7046 => (866) 287-7046
# (408) 347-0990 => (408) 347-0990

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
### data.py
import re


street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

mapping = { "St": "Street",
            "St.": "Street",
            "Rd": "Road",
            "Rd.": "Road",
            "Rd.,": "Road",
            "Ave": "Avenue",
            "ave": "Avenue",
            "Ave.": "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Cir": "Circle",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Hwy":"Highway",
            "Ct": "Court",
            "Pkwy": "Parkway",
            "Ln": "Lane",
            "Sq": "Square",
            "Ste": "Suite",
            "Real":"Real",
            "Saratoga":"Saratoga",
            "Alameda": "Alameda",
            "Way": "Way",
            "Expressway": "Expressway"
            }

def update_name(name, mapping):
    
    m = street_type_re.search(name)
    new_name = name
    if m:
        street_type = m.group()
        if street_type in mapping:
            new_name = street_type_re.sub(mapping[street_type], name)  
    return new_name

import phonenumbers
def update_phone_number(phone_no):
    for match in phonenumbers.PhoneNumberMatcher(phone_no, "US"):
        return phonenumbers.format_number(match.number, phonenumbers.PhoneNumberFormat.NATIONAL)

import zipcodes
def update_zipcode(zipcode):
    #return re.sub('(\d{5})-\d{4}', '\\1', zipcode)
    #print(zipcode)
    b = re.findall(r'\d+', zipcode)
    if b: 
        return b[0]

import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

#OSM_PATH = "san-jose_california_cleaned.osm"
OSM_PATH = "des_moines.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
    #The "node" field should hold a dictionary of the following top level node attributes:
    if element.tag == 'node':
        for attributes in node_attr_fields :
            if attributes in element.attrib :
                node_attribs[attributes] = element.attrib[attributes]

        for elem in element:
            if elem.tag == 'tag':
                temp_tags = {}
                for tagname in NODE_TAGS_FIELDS:
                    if tagname == 'id':
                        temp_tags['id'] = element.attrib['id']
                    elif tagname == 'key':
                        key = elem.attrib['k']
                        m = PROBLEMCHARS.search(key)
                        if m:
                            continue
                        else:
                            if ':' in key:
                                temp_tags['type'], temp_tags['key'] = key.split(':', 1)
                                if key == "addr:street" :
                                    temp_tags['value'] = update_name(elem.attrib['v'],mapping)
                                elif key == "addr:postcode" :
                                    temp_tags['value'] = update_zipcode(elem.attrib['v'])
                                elif key == "contact:phone" :
                                    temp_tags['value'] = update_phone_number(elem.attrib['v'])
                                else :
                                    temp_tags['value'] = elem.attrib['v']
                            else:
                                if key == "phone":
                                    temp_tags['type'] = default_tag_type
                                    temp_tags['key'] = key
                                    temp_tags['value'] = update_phone_number(elem.attrib['v'])
                                else:
                                    temp_tags['type'] = default_tag_type
                                    temp_tags['key'] = key
                                    temp_tags['value'] = elem.attrib['v']

                tags.append(temp_tags)
    
    elif element.tag == 'way':
        for attributes in way_attr_fields :
            if attributes in element.attrib:
                way_attribs[attributes] = element.attrib[attributes]
            
        for counter, elem in enumerate(element):
            if elem.tag == 'nd':
                temp_way_nodes = {}
                for tagname in WAY_NODES_FIELDS:
                    if tagname == 'id':
                        temp_way_nodes['id'] = element.attrib['id']
                    elif tagname == 'node_id':
                        temp_way_nodes['node_id'] = elem.attrib['ref']
                    elif tagname == 'position':
                        temp_way_nodes['position'] = counter
                way_nodes.append(temp_way_nodes)

            if elem.tag == 'tag':
                temp_way_tags = {}
                for tagname in WAY_TAGS_FIELDS:
                    if tagname == 'id':
                        temp_way_tags['id'] = element.attrib['id']
                    elif tagname == 'key':
                        key = elem.attrib['k']
                        m = PROBLEMCHARS.search(key)
                        if m:
                            continue
                        else:
                            if ':' in key:
                                temp_way_tags['type'], temp_way_tags['key'] = key.split(':', 1)
                                if key == "addr:street" :
                                    temp_way_tags['value'] = update_name(elem.attrib['v'],mapping)
                                elif key == "addr:postcode" :
                                    temp_way_tags['value'] = update_zipcode(elem.attrib['v'])
                                elif key == "contact:phone" :
                                     temp_way_tags['value'] = update_phone_number(elem.attrib['v'])
                                else :
                                    temp_way_tags['value'] = elem.attrib['v']
                            else:
                                if key == "phone":
                                    temp_way_tags['type'] = default_tag_type
                                    temp_way_tags['key'] = key
                                    temp_way_tags['value'] = update_phone_number(elem.attrib['v'])
                                else:
                                    temp_way_tags['type'] = default_tag_type
                                    temp_way_tags['key'] = key
                                    temp_way_tags['value'] = elem.attrib['v']

                                
                tags.append(temp_way_tags)

    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

    
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.items())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, str) else v) for k, v in row.items()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
# Out:
# Key:  phone
# +1 515 989 3801
# Key:  phone
# +1 515 989 0097
# Key:  phone
# +1 515 285 3200
# Key:  phone
# +1 515 981 4269
# Key:  phone
# +1 515 981 0224
# Key:  phone
# 515-981-0604
# Key:  phone
# +1 515 981 0556
# Key:  phone
# +1 515 994 3562
# Key:  phone
# +1 515 992 3711
# Key:  phone
# +1 515 262 9303
# Key:  phone
# +1 515 247 3150
# Key:  phone
# +1 515 266 1106
# Key:  phone
# +1 515 262 5639
# Key:  phone
# +1 515 262 0349
# Key:  phone
# 515-271-4747
# Key:  phone
# (515) 255-6720
# Key:  phone
# +1 515 967 3726
# Key:  phone
# 515-288-3353
# Key:  phone
# 515-279-8877
# Key:  phone
# +15152443182
# Key:  phone
# 515-243-4055
# Key:  phone
# +1 515 266 7622
# Key:  phone
# +1 515 809 0608
# Key:  phone
# +1 515 262 7467
# Key:  phone
# 515-244-3101
# Key:  phone
# 515-255-2181
# Key:  phone
# +1 515 967 0133
# Key:  phone
# +1 515 967 0788
# Key:  phone
# +1 515 994 2308
# Key:  phone
# +15159634500
# Key:  phone
# +15159640684
# Key:  phone
# +15159634343
# Key:  phone
# +15159657711
# Key:  phone
# +15159653939
# Key:  phone
# +15159630362
# Key:  phone
# +15159650452‎
# Key:  phone
# +15159633373
# Key:  phone
# +15152774405
# Key:  phone
# +15159649510
# Key:  phone
# +15152481780
# Key:  phone
# +15152890600
# Key:  phone
# +15152625511
# Key:  phone
# +15159630000
# Key:  phone
# +15159653985
# Key:  phone
# +15152444104
# Key:  phone
# +15152433085
# Key:  phone
# +15152831784
# Key:  phone
# +15152888014
# Key:  phone
# +15159651653
# Key:  phone
# +15152894474
# Key:  phone
# +15152994390
# Key:  phone
# (515) 243-7271
# Key:  phone
# +1 515 287 4578
# Key:  phone
# (515) 225-9330
# Key:  phone
# (515) 279-4408
# Key:  phone
# (515) 226-8921
# Key:  phone
# (515) 255-6213
# Key:  phone
# +1 515 279 2919
# Key:  phone
# +1 515 255 4464
# Key:  phone
# +1 515 279 4711
# Key:  phone
# +1 515 277 6351
# Key:  phone
# +1 515 277 6344
# Key:  phone
# +1 515 277 5800
# Key:  phone
# +1 515 279 2911
# Key:  phone
# +1 515 255 1625
# Key:  phone
# +1 515 277 7651
# Key:  phone
# +1 515 279 1002
# Key:  phone
# +1 515 279 9557
# Key:  phone
# +1 515 244 8786
# Key:  phone
# (515) 285-7266
# Key:  phone
# +1 515 222 2755
# Key:  phone
# (515) 270-2225
# Key:  phone
# +1 515 255 1124
# Key:  phone
# +1 515 288 2541
# Key:  phone
# +1 515 619 5358
# Key:  phone
# +1 515 288 3410
# Key:  phone
# +1 515 777 3416
# Key:  phone
# +1 515 867 3674
# Key:  phone
# (800)463-3339
# Key:  phone
# (515)331-4628
# Key:  phone
# (515) 226-1729
# Key:  phone
# 515-276-9602
# Key:  phone
# 515-255-5787
# Key:  phone
# +1 515 256 9000
# Key:  phone
# 515-205-9010
# Key:  phone
# 515-954-7515
# Key:  phone
# 515-259-8110
# Key:  phone
# 515-710-1656
# Key:  phone
# +1 515 537 5652
# Key:  phone
# (515) 288-1050
# Key:  phone
# (515) 333-4620
# Key:  phone
# (515) 279-4855
# Key:  phone
# +1 515 274 6854
# Key:  phone
# (515) 244-2111
# Key:  phone
# (515) 271-0332
# Key:  phone
# +1 515 277 7828
# Key:  phone
# +1 515 255 1167
# Key:  phone
# +1 515 288 1499
# Key:  phone
# +1 515 277 6560
# Key:  phone
# +1 515 953 0226
# Key:  phone
# +1 515 255 2500
# Key:  phone
# +1 515 274 0411
# Key:  phone
# +1 515 279 8818
# Key:  phone
# +1 515 279 2995
# Key:  phone
# +1 515 223 5106
# Key:  phone
# +1 515 288 0541
# Key:  phone
# +1 515 274 3444
# Key:  phone
# +1 515 274 9495
# Key:  phone
# +1 515 255 2443
# Key:  phone
# +1 515 279 3189
# Key:  phone
# +1 515 255 7414
# Key:  phone
# +1 515 274 1518
# Key:  phone
# +1 515 279 2544
# Key:  phone
# +1 515 277 4629
# Key:  phone
# +1 515 277 7421
# Key:  phone
# +1 515 255 6902
# Key:  phone
# +1 515 226 8871
# Key:  phone
# +1 515 334 9917
# Key:  phone
# +1 515 255 9247
# Key:  phone
# +1 515 277 0366
# Key:  phone
# +1 515 237 3974
# Key:  phone
# +1 515 559 3650
# Key:  phone
# +1 515 246 8055
# Key:  phone
# +1 515 528 2329
# Key:  phone
# (515) 221-2751
# Key:  phone
# 515-280-1026
# Key:  phone
# 515-225-4892
# Key:  phone
# (515) 223-8506
# Key:  phone
# (515) 965-7786
# Key:  phone
# 515-207-5430
# Key:  phone
# +1 515 440 1144
# Key:  phone
# +1 515 244 0655
# Key:  phone
# +1 515 288 4872
# Key:  phone
# 1 (515) 276-5182
# Key:  phone
# 1 (515) 334-3000
# Key:  phone
# +1 515 243 1754
# Key:  phone
# +1 515 277 0262
# Key:  phone
# +1 515 270 0824
# Key:  phone
# (515) 243-7152
# Key:  phone
# (515) 288-3631
# Key:  phone
# (515) 283-4500
# Key:  phone
# (515) 283-4213
# Key:  phone
# (515) 283-4284
# Key:  phone
# (515) 283-4046
# Key:  phone
# (515) 283-4200
# Key:  phone
# (515) 283-4182
# Key:  phone
# (515) 283-4209
# Key:  phone
# (515) 283-4141
# Key:  phone
# 515-283-4795
# Key:  phone
# (515) 283-4017
# Key:  phone
# (515) 283-4920
# Key:  phone
# 515-283-4109
# Key:  phone
# 515-283-4973
# Key:  phone
# (515) 283-4921
# Key:  phone
# 515-283-4130
# Key:  phone
# (515) 283-4944
# Key:  phone
# (515) 283-4060
# Key:  phone
# (515) 283-4284
# Key:  phone
# (515) 237-1386
# Key:  phone
# (515) 283-4944
# Key:  phone
# +1 515 2517801
# Key:  phone
# 515-243-8282
# Key:  phone
# 515-777-7979
# Key:  phone
# +1-515-225-6232
# Key:  phone
# 515-883-2245
# Key:  phone
# +1-515-225-2660
# Key:  phone
# +1 515-967-0773
# Key:  phone
# +1 515 994 2210
# Key:  phone
# +1 515 989 3180
# Key:  phone
# +1 515 265 5348
# Key:  phone
# +1 515 967 4267
# Key:  phone
# +1 515 528 2326
# Key:  phone
# +1 515 247 8400
# Key:  phone
# (515) 278-1176
# Key:  phone
# +1-515-440-4960
# Key:  phone
# 5152850654
# Key:  phone
# (515) 967-3765
# Key:  phone
# (515) 964-0656
# Key:  phone
# (515) 964-9464
# Key:  phone
# (515) 287-1022
# Key:  phone
# (515) 262-2108
# Key:  phone
# (515) 246-1390
# Key:  phone
# (515) 285-7133
# Key:  phone
# (515) 986-4527
# Key:  phone
# (515) 270-9212
# Key:  phone
# (515) 265-6144
# Key:  phone
# (515) 216-2762
# Key:  phone
# +1-515-710-9937
